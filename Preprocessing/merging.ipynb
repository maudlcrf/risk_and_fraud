# %%
import pandas as pd
import numpy as np

# %%
fed_fund_rate = pd.read_csv('/Users/andreabordon/Documents/GitHub/risk_and_fraud/US_Datasets/fed_fund_rate_quarterly.csv')

# %%
fed_fund_rate
# Out:
#      quarter  fed_fund_rate
# 0    Q4-1979      13.649333
# 1    Q1-1980      15.065275
# 2    Q2-1980      12.668901
# 3    Q3-1980       9.823152
# 4    Q4-1980      15.852826
# ..       ...            ...
# 177  Q1-2024       5.330000
# 178  Q2-2024       5.330000
# 179  Q3-2024       5.264783
# 180  Q4-2024       4.647935
# 181  Q1-2025       4.330000
#
# [182 rows x 2 columns]

# %%
gdp_qoq_change = pd.read_csv('/Users/andreabordon/Documents/GitHub/risk_and_fraud/US_Datasets/gdp_qoq_change_quarterly.csv')

# %%
gdp_qoq_change
# Out:
#      quarter  gdp_percentage_change_prev_q
# 0    Q2-1947                           4.7
# 1    Q3-1947                           6.0
# 2    Q4-1947                          17.3
# 3    Q1-1948                           9.6
# 4    Q2-1948                          10.7
# ..       ...                           ...
# 305  Q3-2023                           7.7
# 306  Q4-2023                           4.8
# 307  Q1-2024                           4.7
# 308  Q2-2024                           5.6
# 309  Q3-2024                           5.0
#
# [310 rows x 2 columns]

# %%
merged_1 = pd.merge(gdp_qoq_change,fed_fund_rate, on = 'quarter')

# %%
merged_1
# Out:
#      quarter  gdp_percentage_change_prev_q  fed_fund_rate
# 0    Q4-1979                           8.7      13.649333
# 1    Q1-1980                          10.0      15.065275
# 2    Q2-1980                           1.1      12.668901
# 3    Q3-1980                           8.7       9.823152
# 4    Q4-1980                          19.3      15.852826
# ..       ...                           ...            ...
# 175  Q3-2023                           7.7       5.259239
# 176  Q4-2023                           4.8       5.330000
# 177  Q1-2024                           4.7       5.330000
# 178  Q2-2024                           5.6       5.330000
# 179  Q3-2024                           5.0       5.264783
#
# [180 rows x 3 columns]

# %% [markdown]
# Preparing and merging gov_effectiveness_perc_rank

# %%
gov_effectiveness_perc_rank = pd.read_csv('/Users/andreabordon/Documents/GitHub/risk_and_fraud/US_Datasets/gov_effectiveness_perc_rank.csv')

# %%
gov_effectiveness_perc_rank
# Out:
#       Country Name             Value  quarter
# 0    United States                ..  Q1-1974
# 1    United States                ..  Q2-1974
# 2    United States                ..  Q3-1974
# 3    United States                ..  Q4-1974
# 4    United States                ..  Q1-1975
# ..             ...               ...      ...
# 195  United States  87.2641525268555  Q4-2022
# 196  United States  87.7358474731445  Q1-2023
# 197  United States  87.7358474731445  Q2-2023
# 198  United States  87.7358474731445  Q3-2023
# 199  United States  87.7358474731445  Q4-2023
#
# [200 rows x 3 columns]

# %%
gov_effectiveness_perc_rank.rename(columns = {'Value':'gov_effectiveness_perc_rank'}, inplace = True)

# %%
merged_1 = pd.merge(merged_1,gov_effectiveness_perc_rank, on = 'quarter')

# %%
merged_1.drop(columns = 'Country Name', inplace = True)

# %% [markdown]
# prepparing monthly_fed_balance and PCECTPI

# %%
monthly_fed_balance = pd.read_csv('/Users/andreabordon/Documents/GitHub/risk_and_fraud/US_Datasets/monthly_fed_balance.csv')

# %%
PCECTPI = pd.read_csv('/Users/andreabordon/Documents/GitHub/risk_and_fraud/US_Datasets/PCECTPI_quarterly.csv')

# %%
monthly_fed_balance
# Out:
#     observation_date    MTSDS133FMS
# 0         1980-10-01  -16921.000000
# 1         1980-11-01   -8907.000000
# 2         1980-12-01   -1965.000000
# 3         1981-01-01  -12192.000000
# 4         1981-02-01  -15620.000000
# ..               ...            ...
# 525       2024-07-01 -243741.087297
# 526       2024-08-01 -380080.405435
# 527       2024-09-01   64263.008868
# 528       2024-10-01 -257450.343192
# 529       2024-11-01 -366763.064368
#
# [530 rows x 2 columns]

# %%
monthly_fed_balance['date'] = pd.to_datetime(monthly_fed_balance['observation_date'])

# %%
monthly_fed_balance
# Out:
#     observation_date    MTSDS133FMS       date
# 0         1980-10-01  -16921.000000 1980-10-01
# 1         1980-11-01   -8907.000000 1980-11-01
# 2         1980-12-01   -1965.000000 1980-12-01
# 3         1981-01-01  -12192.000000 1981-01-01
# 4         1981-02-01  -15620.000000 1981-02-01
# ..               ...            ...        ...
# 525       2024-07-01 -243741.087297 2024-07-01
# 526       2024-08-01 -380080.405435 2024-08-01
# 527       2024-09-01   64263.008868 2024-09-01
# 528       2024-10-01 -257450.343192 2024-10-01
# 529       2024-11-01 -366763.064368 2024-11-01
#
# [530 rows x 3 columns]

# %%
import pandas as pd

# Ensure 'date' column is in datetime format
monthly_fed_balance['date'] = pd.to_datetime(monthly_fed_balance['date'])

# Create a 'quarter' column in the format 'QX-YYYY'
monthly_fed_balance['quarter'] = 'Q' + monthly_fed_balance['date'].dt.quarter.astype(str) + '-' + monthly_fed_balance['date'].dt.year.astype(str)

# %%
quarterly_fed_balance = monthly_fed_balance.groupby('quarter', as_index=False)['MTSDS133FMS'].mean()

# %%
quarterly_fed_balance.rename(columns = {'MTSDS133FMS':'quarterly_fed_balance'}, inplace = True)

# %%
quarterly_fed_balance
# Out:
#      quarter  quarterly_fed_balance
# 0    Q1-1981          -12464.666667
# 1    Q1-1982           -7898.666667
# 2    Q1-1983          -20318.000000
# 3    Q1-1984          -18150.333333
# 4    Q1-1985          -19515.666667
# ..       ...                    ...
# 172  Q4-2020         -190966.376047
# 173  Q4-2021         -125897.845627
# 174  Q4-2022         -140444.484514
# 175  Q4-2023         -169980.322779
# 176  Q4-2024         -312106.703780
#
# [177 rows x 2 columns]

# %%
PCECTPI
# Out:
#      quarter  PCECTPI
# 0    Q1-1947   11.557
# 1    Q2-1947   11.649
# 2    Q3-1947   11.866
# 3    Q4-1947   12.162
# 4    Q1-1948   12.297
# ..       ...      ...
# 306  Q3-2023  120.983
# 307  Q4-2023  121.480
# 308  Q1-2024  122.507
# 309  Q2-2024  123.275
# 310  Q3-2024  123.747
#
# [311 rows x 2 columns]

# %%
merged_1 = pd.merge(merged_1,PCECTPI, on = 'quarter')

# %%
merged_1
# Out:
#      quarter  gdp_percentage_change_prev_q  fed_fund_rate  \
# 0    Q4-1979                           8.7      13.649333
# 1    Q1-1980                          10.0      15.065275
# 2    Q2-1980                           1.1      12.668901
# 3    Q3-1980                           8.7       9.823152
# 4    Q4-1980                          19.3      15.852826
# ..       ...                           ...            ...
# 172  Q4-2022                           7.2       3.653370
# 173  Q1-2023                           6.6       4.514556
# 174  Q2-2023                           4.3       4.988132
# 175  Q3-2023                           7.7       5.259239
# 176  Q4-2023                           4.8       5.330000
#
#     gov_effectiveness_perc_rank  PCECTPI
# 0                            ..   36.451
# 1                            ..   37.545
# 2                            ..   38.464
# 3                            ..   39.364
# 4                            ..   40.338
# ...

# %%
merged_1 = pd.merge(merged_1,quarterly_fed_balance, on = 'quarter')

# %%
merged_1
# Out:
#      quarter  gdp_percentage_change_prev_q  fed_fund_rate  \
# 0    Q4-1980                          19.3      15.852826
# 1    Q1-1981                          19.9      16.595556
# 2    Q2-1981                           5.0      17.786923
# 3    Q3-1981                          13.0      17.594348
# 4    Q4-1981                           2.5      13.588370
# ..       ...                           ...            ...
# 168  Q4-2022                           7.2       3.653370
# 169  Q1-2023                           6.6       4.514556
# 170  Q2-2023                           4.3       4.988132
# 171  Q3-2023                           7.7       5.259239
# 172  Q4-2023                           4.8       5.330000
#
#     gov_effectiveness_perc_rank  PCECTPI  quarterly_fed_balance
# 0                            ..   40.338           -9264.333333
# 1                            ..   41.384          -12464.666667
# 2                            ..   42.078            5460.666667
# ...

# %%
political_stability = pd.read_csv('/Users/andreabordon/Documents/GitHub/risk_and_fraud/US_Datasets/Political_Stability_USA.csv')
producer_price_index = pd.read_csv('/Users/andreabordon/Documents/GitHub/risk_and_fraud/US_Datasets/producer_price_index_quarterly.csv')
target_us = pd.read_csv('/Users/andreabordon/Documents/GitHub/risk_and_fraud/US_Datasets/target_us.csv')

# %% [markdown]
# Preparing for merge

# %%
political_stability.rename(columns= {'Value' : 'political_stability_perc_rank'}, inplace = True)

# %%
political_stability.drop(columns = 'Country Name', inplace = True)

# %%
target_us.drop(columns = 'Unnamed: 0', inplace = True)

# %%
target_us.rename(columns= {'Quarter' : 'quarter'}, inplace = True)

# %%
merged_1 = pd.merge(merged_1,target_us, on = 'quarter')

# %%
merged_1 = pd.merge(merged_1,political_stability, on = 'quarter')

# %%
merged_1
# Out:
#     quarter  gdp_percentage_change_prev_q  fed_fund_rate  \
# 0   Q1-2000                           4.2       5.677692
# 1   Q2-2000                          10.2       6.271978
# 2   Q3-2000                           2.8       6.519457
# 3   Q4-2000                           4.6       6.474891
# 4   Q1-2001                           1.3       5.597000
# ..      ...                           ...            ...
# 91  Q4-2022                           7.2       3.653370
# 92  Q1-2023                           6.6       4.514556
# 93  Q2-2023                           4.3       4.988132
# 94  Q3-2023                           7.7       5.259239
# 95  Q4-2023                           4.8       5.330000
#
#    gov_effectiveness_perc_rank  PCECTPI  quarterly_fed_balance Bond Rating  \
# 0             91.8032760620117   73.219           -4987.333333          AA
# 1             91.8032760620117   73.568           70591.333333          AA
# ...

# %%
merged_1 = pd.merge(merged_1,producer_price_index, on = 'quarter')

# %% [markdown]
# preparing last three CSV

# %%
tax_rev_perc_gdp = pd.read_csv('/Users/andreabordon/Documents/GitHub/risk_and_fraud/US_Datasets/tax_rev_perc_gdp.csv')
unemployment_cost_index = pd.read_csv('/Users/andreabordon/Documents/GitHub/risk_and_fraud/US_Datasets/unemployment_cost_index_quarterly.csv')
unemployment_rate = pd.read_csv('/Users/andreabordon/Documents/GitHub/risk_and_fraud/US_Datasets/unemployment_rate_quarterly.csv')

# %% [markdown]
# Preparing df for merge

# %%
tax_rev_perc_gdp.rename(columns = {'Value': "tax_rev_perc_gdp"}, inplace = True)

# %%
tax_rev_perc_gdp.drop(columns = 'Country Name', inplace = True)

# %%
merged_1 = pd.merge(merged_1,tax_rev_perc_gdp, on = 'quarter')

# %%
merged_1 = pd.merge(merged_1,unemployment_cost_index, on = 'quarter')

# %%
merged_1 = pd.merge(merged_1,unemployment_rate, on = 'quarter')

# %%
merged_1
# Out:
#     quarter  gdp_percentage_change_prev_q  fed_fund_rate  \
# 0   Q1-2001                           1.3       5.597000
# 1   Q2-2001                           5.0       4.326703
# 2   Q3-2001                           0.0       3.501522
# 3   Q4-2001                           2.4       2.130435
# 4   Q1-2002                           4.7       1.732889
# ..      ...                           ...            ...
# 87  Q4-2022                           7.2       3.653370
# 88  Q1-2023                           6.6       4.514556
# 89  Q2-2023                           4.3       4.988132
# 90  Q3-2023                           7.7       5.259239
# 91  Q4-2023                           4.8       5.330000
#
#    gov_effectiveness_perc_rank  PCECTPI  quarterly_fed_balance Bond Rating  \
# 0                           ..   75.012           -7483.666667          AA
# 1                           ..   75.363           64579.666667           A
# ...

# %%
Federal_Debt_FED_perc_gdp = pd.read_csv('/Users/andreabordon/Documents/GitHub/risk_and_fraud/US_Datasets/Federal_Debt_FED_perc_gdp.csv')
federal_debt_foreign_investors = pd.read_csv('/Users/andreabordon/Documents/GitHub/risk_and_fraud/US_Datasets/federal_debt_foreign_investors.csv')
federal_debt_private_investors_perc_gdp = pd.read_csv('/Users/andreabordon/Documents/GitHub/risk_and_fraud/US_Datasets/federal_debt_private_investors_perc_gdp.csv')

# %%
federal_debt_foreign_investors.drop(columns = 'Unnamed: 0', inplace =True)

# %%
federal_debt_private_investors_perc_gdp.drop(columns = 'Unnamed: 0', inplace =True)

# %%
Federal_Debt_FED_perc_gdp
# Out:
#      Unnamed: 0  Federal_Debt_FED_perc_GDP  quarter
# 0             0                    5.30822  Q1-1970
# 1             1                    5.40579  Q2-1970
# 2             2                    5.52456  Q3-1970
# 3             3                    5.70453  Q4-1970
# 4             4                    5.65561  Q1-1971
# ..          ...                        ...      ...
# 214         214                   19.13765  Q3-2023
# 215         215                   18.51413  Q4-2023
# 216         216                   17.43728  Q1-2024
# 217         217                   16.58989  Q2-2024
# 218         218                   16.04762  Q3-2024
#
# [219 rows x 3 columns]

# %%
merged_1 = pd.merge(merged_1,Federal_Debt_FED_perc_gdp, on = 'quarter')

# %%
merged_1.drop(columns = 'Unnamed: 0', inplace =True)

# %%
merged_1 = pd.merge(merged_1,federal_debt_foreign_investors, on = 'quarter')

# %%
merged_1 = pd.merge(merged_1,federal_debt_private_investors_perc_gdp, on = 'quarter')

# %%
merged_1
# Out:
#     quarter  gdp_percentage_change_prev_q  fed_fund_rate  \
# 0   Q1-2001                           1.3       5.597000
# 1   Q2-2001                           5.0       4.326703
# 2   Q3-2001                           0.0       3.501522
# 3   Q4-2001                           2.4       2.130435
# 4   Q1-2002                           4.7       1.732889
# ..      ...                           ...            ...
# 87  Q4-2022                           7.2       3.653370
# 88  Q1-2023                           6.6       4.514556
# 89  Q2-2023                           4.3       4.988132
# 90  Q3-2023                           7.7       5.259239
# 91  Q4-2023                           4.8       5.330000
#
#    gov_effectiveness_perc_rank  PCECTPI  quarterly_fed_balance Bond Rating  \
# 0                           ..   75.012           -7483.666667          AA
# 1                           ..   75.363           64579.666667           A
# ...

# %%
merged_1.rename(columns = {'Federal_Debt_FED_perc_GDP' : 'federal_debt_FED_perc_gdp'}, inplace =True)

# %%
merged_1
# Out:
#     quarter  gdp_percentage_change_prev_q  fed_fund_rate  \
# 0   Q1-2001                           1.3       5.597000
# 1   Q2-2001                           5.0       4.326703
# 2   Q3-2001                           0.0       3.501522
# 3   Q4-2001                           2.4       2.130435
# 4   Q1-2002                           4.7       1.732889
# ..      ...                           ...            ...
# 87  Q4-2022                           7.2       3.653370
# 88  Q1-2023                           6.6       4.514556
# 89  Q2-2023                           4.3       4.988132
# 90  Q3-2023                           7.7       5.259239
# 91  Q4-2023                           4.8       5.330000
#
#    gov_effectiveness_perc_rank  PCECTPI  quarterly_fed_balance Bond Rating  \
# 0                           ..   75.012           -7483.666667          AA
# 1                           ..   75.363           64579.666667           A
# ...

# %%
merged_1.to_csv('merged_us')
