# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/andreabordon/Documents/GitHub/risk_and_fraud/US_Datasets/merged_us.csv')

# %% [markdown]
# dropping an index column

# %%
df.drop(columns = 'Unnamed: 0', inplace = True)

# %%
df.isna().mean()
# Out:
# quarter                                    0.0
# gdp_percentage_change_prev_q               0.0
# fed_fund_rate                              0.0
# gov_effectiveness_perc_rank                0.0
# PCECTPI                                    0.0
# quarterly_fed_balance                      0.0
# Bond Rating                                0.0
# political_stability_perc_rank              0.0
# producer_price                             0.0
# tax_rev_perc_gdp                           0.0
# employment_cost                            0.0
# unemployment_rate                          0.0
# federal_debt_FED_perc_gdp                  0.0
# federal_debt_foreign_investors             0.0
# federal_debt_private_investors_perc_gdp    0.0
# dtype: float64

# %% [markdown]
# filling gov_effectiveness_perc_rank with previous value

# %%
df['gov_effectiveness_perc_rank'] = pd.to_numeric(df['gov_effectiveness_perc_rank'], errors='coerce')

# %%
df['gov_effectiveness_perc_rank'] = df['gov_effectiveness_perc_rank'].fillna(89)

# %% [markdown]
# filling political_stability_perc_rank as well

# %%
df['political_stability_perc_rank'] = pd.to_numeric(df['political_stability_perc_rank'], errors='coerce')

# %%
df
# Out:
#     quarter  gdp_percentage_change_prev_q  fed_fund_rate  \
# 0   Q1-2001                           1.3       5.597000
# 1   Q2-2001                           5.0       4.326703
# 2   Q3-2001                           0.0       3.501522
# 3   Q4-2001                           2.4       2.130435
# 4   Q1-2002                           4.7       1.732889
# ..      ...                           ...            ...
# 87  Q4-2022                           7.2       3.653370
# 88  Q1-2023                           6.6       4.514556
# 89  Q2-2023                           4.3       4.988132
# 90  Q3-2023                           7.7       5.259239
# 91  Q4-2023                           4.8       5.330000
#
#     gov_effectiveness_perc_rank  PCECTPI  quarterly_fed_balance Bond Rating  \
# 0                     89.000000   75.012           -7483.666667          AA
# 1                     89.000000   75.363           64579.666667           A
# ...

# %%
df['political_stability_perc_rank'] =df['political_stability_perc_rank'].fillna(50)

# %%
df
# Out:
#     quarter  gdp_percentage_change_prev_q  fed_fund_rate  \
# 0   Q1-2001                           1.3       5.597000
# 1   Q2-2001                           5.0       4.326703
# 2   Q3-2001                           0.0       3.501522
# 3   Q4-2001                           2.4       2.130435
# 4   Q1-2002                           4.7       1.732889
# ..      ...                           ...            ...
# 87  Q4-2022                           7.2       3.653370
# 88  Q1-2023                           6.6       4.514556
# 89  Q2-2023                           4.3       4.988132
# 90  Q3-2023                           7.7       5.259239
# 91  Q4-2023                           4.8       5.330000
#
#     gov_effectiveness_perc_rank  PCECTPI  quarterly_fed_balance Bond Rating  \
# 0                     89.000000   75.012           -7483.666667          AA
# 1                     89.000000   75.363           64579.666667           A
# ...
